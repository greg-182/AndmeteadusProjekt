# %%
import pandas as pd

df = pd.read_parquet("data/merged_reports.parquet")

# %%
df.head()
# Out:
#    report_id  Assets  AssetsConsolidated  \
# 0     994318   946.0                 NaN
# 1    1262635     NaN                 NaN
# 2    1434010  2370.0                 NaN
# 3    1434860  2560.0                 NaN
# 4    1435129     4.0                 NaN
#
#    AverageNumberOfEmployeesInFullTimeEquivalentUnits  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    AverageNumberOfEmployeesInFullTimeEquivalentUnitsConsolidated  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df.count()
# Out:
# report_id                                                        1439777
# Assets                                                           1426025
# AssetsConsolidated                                                  5280
# AverageNumberOfEmployeesInFullTimeEquivalentUnits                1426965
# AverageNumberOfEmployeesInFullTimeEquivalentUnitsConsolidated       5280
# BusinessIncome                                                     75526
# CashAndCashEquivalents                                           1018791
# CashAndCashEquivalentsConsolidated                                  5276
# CurrentAssets                                                    1411973
# CurrentAssetsConsolidated                                           5280
# CurrentLiabilities                                               1176871
# CurrentLiabilitiesConsolidated                                      5262
# DepreciationAndImpairmentLossReversal                             632591
# ...
